# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data Set

# %%
data_set1=pd.read_csv(r"C:\Users\jeeva\Documents\Machine Learning\poly_regression.csv")
data_set=data_set1.copy()

# %%
X=data_set.iloc[:,:-1].values
y=data_set.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=6)
X_poly=poly_reg.fit_transform(X)

regressor1=LinearRegression()
regressor1.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,y,color='red')
plt.plot(X,regressor.predict(X),color='blue')
plt.title("RBC-linear regression")
plt.xlabel("age")
plt.ylabel('rbc')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
plt.scatter(X,y,color='red')
plt.plot(X,regressor1.predict(X_poly),color='blue')
plt.title("RBC- polynomial linear regression")
plt.xlabel("age")
plt.ylabel('rbc')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regressor.predict([[6.5],[20],[50],[85]])
# Out:
# array([1980.15863901, 1754.160511  , 1251.94244877,  666.02137617])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
regressor1.predict(poly_reg.fit_transform([[6.5],[20],[50],[85]]))
# Out:
# array([ 878.06397602, 2602.59823029, 1621.91561623,   82.26809801])
